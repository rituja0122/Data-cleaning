# %% [markdown]
# ##### To drop null values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("food_coded.csv")

# %% [markdown]
# ##### To delete a particular column/columns

# %%
data.drop(columns=["type_sports"],inplace=True)
#inplace modifies in original dataset
data.head(3)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
#
#    coffee                     comfort_food   comfort_food_reasons  \
# 0       1                             none  we dont have comfort
# 1       2      chocolate, chips, ice cream   Stress, bored, anger
# 2       2  frozen yogurt, pizza, fast food        stress, sadness
#
#    comfort_food_reasons_coded  ...  self_perception_weight  soup  sports  \
# 0                         9.0  ...                     3.0   1.0     1.0
# 1                         1.0  ...                     3.0   1.0     1.0
# 2                         1.0  ...                     6.0   1.0     2.0
#
#   thai_food  tortilla_calories  turkey_calories veggies_day  vitamins  \
# ...

# %%
data.shape
# Out:
# (125, 60)

# %% [markdown]
# ##### To delete all rows containing null values

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (57, 60)

# %%
sns.heatmap(data.isnull())
plt.show()
